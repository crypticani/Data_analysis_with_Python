# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniketkjnv/Data_analysis_with_Python/blob/master/image_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **WAC Machine Learning Webinar**

# %% [markdown]
# Working on an image imported through wget.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
print(cv2.__version__)
# Out:
# 4.1.2

# %%
# !pip install numpy

# %%
# !wget "https://www.dropbox.com/s/ant0qs3j9rp1t5l/messi.jpg?"
# Out:
# --2020-04-24 12:12:36--  https://www.dropbox.com/s/ant0qs3j9rp1t5l/messi.jpg?
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:601f:1::a27d:901
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/ant0qs3j9rp1t5l/messi.jpg [following]
# --2020-04-24 12:12:36--  https://www.dropbox.com/s/raw/ant0qs3j9rp1t5l/messi.jpg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc853222623d44ff35eb8c8c3e23.dl.dropboxusercontent.com/cd/0/inline/A2d1lvkuQY5HNUz2A1OacrK04GUAg4ISAowGW7qNePLX_IYMuL3e3WcHFu4GhxS3bqJgUchbc6GEX2KR8sRQ29geHxhSL4iYu6JF0CEyV-KhhI8gWiivJzlC2H-05p_YKYQ/file# [following]
# ...

# %%
img = cv2.imread('messi.jpg?.3')

# %%
if img is None:
  print("open error")
else:
  print("image loaded")
# Out:
# image loaded

# %%
#cv2.imshow('messi',img)

# %%
print(img.shape)
# Out:
# (342, 548, 3)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img[:2,:2])
# Out:
# [[[39 43 44]
#   [42 46 47]]
#
#  [[37 40 44]
#   [42 45 49]]]

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
for i in range(5):
  for j in range(5):
    img[50+i,235+j] = (0,255,0)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
ball = img[280:340,300:390]

# %%
plt.imshow(ball)

# %%
plt.imshow(cv2.cvtColor(ball,cv2.COLOR_BGR2RGB))
